# %% [markdown]
# # CNN-Challenge-B: particle image segmentation
#
# This notebook is to introduce the dataset for a particle image segmentation challenge. Two type of particle trajectories, _track_ and _shower_, are simulated in liquid argon medium and the 2D projections of their 3D energy deposition patterns ("trajectories") are recorded. The challenge is to develop the pixel level classifier algorithm that can identify every pixel's type into one of three categories: background, shower, or track.

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
mpl.rcParams['figure.figsize'] = [8, 6]
mpl.rcParams['font.size'] = 16
mpl.rcParams['axes.grid'] = True

import torch
torch.multiprocessing.set_start_method('spawn')
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

import numpy as np

# %% [markdown]
# ## Data files
#
# * Here's the data file location: `/sdf/group/slacml-school/kmi2020/image_segmentation/`
# * A data file with 25,000 images for training: `train.h5`
# * A data file with 4,000 images for validation: `val.h5`
# * A data file with 10,000 images for testing: `test.h5`
#
# These files are `HDF5` files and can be opened using `h5py`.

# %%
import h5py as h5
datapath='/sdf/group/slacml-school/kmi2020/image_segmentation/train.h5'

# Open a file in 'r'ead mode.
f=h5.File(datapath,mode='r',swmr=True) 

# List items in the file
for key in f.keys():
    print('dataset',key,'... type',f[key].dtype,'... shape',f[key].shape)
# Out:
# dataset image ... type float32 ... shape (25000, 256, 256)
# dataset index ... type int32 ... shape (25000,)
# dataset label ... type float32 ... shape (25000, 256, 256)

# %% [markdown]
# ... and let's visualize one image for fun!

# %%
entry = 5
fig,axes=plt.subplots(1,2,figsize=(16,8))
axes[0].imshow(f['image'][entry],origin='lower')
axes[1].imshow(f['label'][entry],origin='lower')
plt.show()

# %% [markdown]
# You can see the `label` image shows discrete color scales, basically 3 colors for 3 classes. We can double-check there are really 3 values.

# %%
print('Unique values in the label image',np.unique(f['label'][entry]))
# Out:
# Unique values in the label image [0. 1. 2.]

# %% [markdown]
# Let's don't forget to close the file :)

# %%
f.close()

# %% [markdown]
# ## Segmentation Image `Dataset` and `DataLoader`
#
# We prepared a simple torch `Dataset` implementation for this dataset.

# %%
from cnn_challenge_b import SegmentImage2D
train_data = SegmentImage2D(data_files=[datapath])

# %% [markdown]
# The dataset is index-accessible and produce a dictionary with four keys
# * `data` ... 2D image of a particle (192x192 pixels) of floating point value (energy deposition)
# * `label` ... 2D image of a particle (256x256 pixels) of integer type for classification
# * `index` ... an index of the data entry from an input file

# %%
print('Size of dataset',len(train_data))

# Access the 5-th instance
data = train_data[5]

# The data instance is a dictionary
print('List of keys in a data element',data.keys(),'\n')

# Visualize the image
print('Again 5-th image!')
fig,axes=plt.subplots(1,2,figsize=(16,8))
axes[0].imshow(data['data'],origin='lower')
axes[1].imshow(data['label'],origin='lower')
plt.show()
# Out:
# Size of dataset 25000
# List of keys in a data element dict_keys(['data', 'label', 'index'])
#
# Again 5-th image!

# %% [markdown]
# Create a `DataLoader` instance in a usual way except we give a specifically designed collate function to handle a dictionary style data instance.

# %%
train_data = SegmentImage2D(data_files = [datapath],
                            num_class = 3,
                            start = 0.0, # start of the dataset fraction to use. 0.0 = use from 1st entry
                            end   = 0.8, # end of the dataset fraction to use. 1.0 = use up the last entry
                            )

# We use a specifically designed "collate" function to create a batch data
from cnn_challenge_b import collate
from torch.utils.data import DataLoader
train_loader = DataLoader(train_data,
                          collate_fn  = collate,
                          shuffle     = True,
                          num_workers = 4,
                          batch_size  = 32
                         )

# %% [markdown]
# Let's measure the speed of the dataloader

# %%
import time
tstart=time.time()
num_iter=10
ctr=num_iter
for batch in train_loader:
    ctr -= 1
print((time.time()-tstart)/num_iter,'[s/iteration]')
# Out:
# 2.6833746910095213 [s/iteration]

# %% [markdown]
# ## Challenge
#
# Here are open-ended challenge project for an image segmentation.
#
# * Design a deep neural network that performs image segmentation task, train, and report the performance.
#
# * Produce the "software score map", an image which pixels showing the highest softmax score across semantic classes. Regions with the low score value are where the classification confidence is low. Do you see a pattern in low confidence regions?
#
# * Inspect the learning process. Which class does your algorithm learn first? Where in the image the classification confidence becomes high in the earlier phase of the training?

# %%
! mkdir -p weights_b

# %%
from uresnet import UResNet

class BLOB:
    pass
blob=BLOB()
blob.device    = device # GPU or CPU
blob.net       = UResNet(3,1,16,[2,2,2,2,2]).to(blob.device) # construct the network, set to the right device
blob.criterion = torch.nn.CrossEntropyLoss(reduction='none') # use softmax loss to define an error
blob.optimizer = torch.optim.Adam(blob.net.parameters()) # use Adam optimizer algorithm
blob.softmax   = torch.nn.Softmax(dim=1) # not for training, but softmax score for each class
blob.iteration = 0    # integer count for the number of train steps
blob.data      = None # data for training/analysis
blob.label     = None # label for training/analysis

# Import train_loop, plot_loss
from utils_challenge_b import train_loop, plot_loss, save_state
blob.weight_file=save_state(blob,prefix='./weights_b/UResNet')
# Train
steps  = [(i+1)*10    for i in range(9)]
steps += [(i+1)*100   for i in range(9)]
steps += [(i+1)*1000  for i in range(9)]
steps += [(i+1)*10000 for i in range(6)]

loss,acc=[],[]
for step in steps[1:]:
    train_result=train_loop(blob,train_loader,num_iteration=step)
    loss.append(train_result['loss'])
    acc.append(train_result['accuracy'])
    blob.weight_file=save_state(blob,prefix='./weights_b/UResNet')
    np.savez('train_log_b.npz', loss=np.hstack(loss),accuracy=np.hstack(acc))
# Out:
#         <progress
#             value='20'
#             max='20',
#             style='width: 30%'
#         >
#             20
#         </progress> 100% Iteration: 20 elapsed 8 [sec] ... Loss: 0.82 Accuracy: 0.80
#         <progress
#             value='30'
#             max='30',
#             style='width: 30%'
#         >
#             30
#         </progress> 100% Iteration: 30 elapsed 5 [sec] ... Loss: 0.66 Accuracy: 0.81
#         <progress
#             value='40'
#             max='40',
#             style='width: 30%'
#         >
#             40
#         </progress> 100% Iteration: 40 elapsed 5 [sec] ... Loss: 0.40 Accuracy: 0.86
#         <progress
#             value='50'
#             max='50',
#             style='width: 30%'
#         >
#             50
#         </progress> 100% Iteration: 50 elapsed 5 [sec] ... Loss: 0.25 Accuracy: 0.92
#         <progress
#             value='60'
#             max='60',
#             style='width: 30%'
#         >
#             60
#         </progress> 100% Iteration: 60 elapsed 5 [sec] ... Loss: 0.24 Accuracy: 0.92
#         <progress
#             value='70'
#             max='70',
#             style='width: 30%'
#         >
#             70
#         </progress> 100% Iteration: 70 elapsed 5 [sec] ... Loss: 0.25 Accuracy: 0.92
#         <progress
#             value='80'
#             max='80',
#             style='width: 30%'
#         >
#             80
#         </progress> 100% Iteration: 80 elapsed 5 [sec] ... Loss: 0.23 Accuracy: 0.91
#         <progress
#             value='90'
#             max='90',
#             style='width: 30%'
#         >
#             90
#         </progress> 100% Iteration: 90 elapsed 6 [sec] ... Loss: 0.14 Accuracy: 0.95
#         <progress
#             value='100'
#             max='100',
#             style='width: 30%'
#         >
#             100
#         </progress> 100% Iteration: 100 elapsed 5 [sec] ... Loss: 0.19 Accuracy: 0.93
#         <progress
#             value='200'
#             max='200',
#             style='width: 30%'
#         >
#             200
#         </progress> 100% Iteration: 200 elapsed 27 [sec] ... Loss: 0.11 Accuracy: 0.96
#         <progress
#             value='300'
#             max='300',
#             style='width: 30%'
#         >
#             300
#         </progress> 100% Iteration: 300 elapsed 26 [sec] ... Loss: 0.12 Accuracy: 0.96
#         <progress
#             value='400'
#             max='400',
#             style='width: 30%'
#         >
#             400
#         </progress> 100% Iteration: 400 elapsed 26 [sec] ... Loss: 0.08 Accuracy: 0.97
#         <progress
#             value='500'
#             max='500',
#             style='width: 30%'
#         >
#             500
#         </progress> 100% Iteration: 500 elapsed 27 [sec] ... Loss: 0.08 Accuracy: 0.97
#         <progress
#             value='600'
#             max='600',
#             style='width: 30%'
#         >
#             600
#         </progress> 100% Iteration: 600 elapsed 26 [sec] ... Loss: 0.08 Accuracy: 0.97
#         <progress
#             value='700'
#             max='700',
#             style='width: 30%'
#         >
#             700
#         </progress> 100% Iteration: 700 elapsed 26 [sec] ... Loss: 0.06 Accuracy: 0.98
#         <progress
#             value='800'
#             max='800',
#             style='width: 30%'
#         >
#             800
#         </progress> 100% Iteration: 800 elapsed 26 [sec] ... Loss: 0.07 Accuracy: 0.97
#         <progress
#             value='900'
#             max='900',
#             style='width: 30%'
#         >
#             900
#         </progress> 100% Iteration: 900 elapsed 26 [sec] ... Loss: 0.07 Accuracy: 0.97
#         <progress
#             value='1000'
#             max='1000',
#             style='width: 30%'
#         >
#             1000
#         </progress> 100% Iteration: 1000 elapsed 27 [sec] ... Loss: 0.10 Accuracy: 0.96
#         <progress
#             value='2000'
#             max='2000',
#             style='width: 30%'
#         >
#             2000
#         </progress> 100% Iteration: 2000 elapsed 241 [sec] ... Loss: 0.08 Accuracy: 0.98
#         <progress
#             value='3000'
#             max='3000',
#             style='width: 30%'
#         >
#             3000
#         </progress> 100% Iteration: 3000 elapsed 242 [sec] ... Loss: 0.04 Accuracy: 0.98
#         <progress
#             value='4000'
#             max='4000',
#             style='width: 30%'
#         >
#             4000
#         </progress> 100% Iteration: 4000 elapsed 241 [sec] ... Loss: 0.02 Accuracy: 0.99
#         <progress
#             value='5000'
#             max='5000',
#             style='width: 30%'
#         >
#             5000
#         </progress> 100% Iteration: 5000 elapsed 243 [sec] ... Loss: 0.03 Accuracy: 0.99
#         <progress
#             value='6000'
#             max='6000',
#             style='width: 30%'
#         >
#             6000
#         </progress> 100% Iteration: 6000 elapsed 242 [sec] ... Loss: 0.03 Accuracy: 0.99
#         <progress
#             value='7000'
#             max='7000',
#             style='width: 30%'
#         >
#             7000
#         </progress> 100% Iteration: 7000 elapsed 242 [sec] ... Loss: 0.01 Accuracy: 0.99
#         <progress
#             value='8000'
#             max='8000',
#             style='width: 30%'
#         >
#             8000
#         </progress> 100% Iteration: 8000 elapsed 242 [sec] ... Loss: 0.03 Accuracy: 0.99
#         <progress
#             value='9000'
#             max='9000',
#             style='width: 30%'
#         >
#             9000
#         </progress> 100% Iteration: 9000 elapsed 242 [sec] ... Loss: 0.01 Accuracy: 1.00
#         <progress
#             value='10000'
#             max='10000',
#             style='width: 30%'
#         >
#             10000
#         </progress> 100% Iteration: 10000 elapsed 242 [sec] ... Loss: 0.01 Accuracy: 1.00
#         <progress
#             value='20000'
#             max='20000',
#             style='width: 30%'
#         >
#             20000
#         </progress> 100% Iteration: 20000 elapsed 2416 [sec] ... Loss: 0.01 Accuracy: 1.00
#         <progress
#             value='30000'
#             max='30000',
#             style='width: 30%'
#         >
#             30000
#         </progress> 100% Iteration: 30000 elapsed 2413 [sec] ... Loss: 0.00 Accuracy: 1.00
#         <progress
#             value='40000'
#             max='40000',
#             style='width: 30%'
#         >
#             40000
#         </progress> 100% Iteration: 40000 elapsed 2412 [sec] ... Loss: 0.00 Accuracy: 1.00
#         <progress
#             value='50000'
#             max='50000',
#             style='width: 30%'
#         >
#             50000
#         </progress> 100% Iteration: 50000 elapsed 2413 [sec] ... Loss: 0.00 Accuracy: 1.00
#         <progress
#             value='59950'
#             max='60000',
#             style='width: 30%'
#         >
#             59950
#         </progress> 99% Iteration: 59950 elapsed 2400 [sec] ... Loss: 0.01 Accuracy: 1.00

# %%
from utils import moving_average

f=np.load('train_log_b.npz')
plt.plot(f['loss'],label='loss')
plt.plot(*moving_average(f['loss'],40),label='average (40 pts)',linewidth=3)
plt.ylim(0.001,2.)
plt.yscale('log')
plt.show()
